# %% [markdown]
# # Coleta de Dados no Twitter utilizando pacote Tweepy do Python e armazena em arquivo, ingestão no SQL Server

# %%
# Install package
! pip install tweepy

# %%
import json

# %%
# Run script to get tweets
# %run get_tweets.py

# %%
# Open the file
with open("collected_tweets_2020-11-25-15-40-41.txt", "r") as file:
    tweets = file.readlines()

# %%
# Write a JSON example
with open ("tweet.json", "w") as file2:
    print(json.dump(
        json.loads(
            json.loads(tweets[0]
                      )
        ), file2))

# %%
# List with tweets parsed in JSON format
parsed_tweets = [json.loads( json.loads(tweet) ) for tweet in tweets]

# %%
# Checking the keys
parsed_tweets[0].keys()
# Out:
# dict_keys(['created_at', 'id', 'id_str', 'text', 'display_text_range', 'source', 'truncated', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'in_reply_to_screen_name', 'user', 'geo', 'coordinates', 'place', 'contributors', 'is_quote_status', 'extended_tweet', 'quote_count', 'reply_count', 'retweet_count', 'favorite_count', 'entities', 'favorited', 'retweeted', 'filter_level', 'lang', 'timestamp_ms'])

# %% [markdown]
# ## Tranformando os Tweets em uma estrutura relacional Pandas Dataframe

# %% [markdown]
# #### Define Functions

# %%
# Import Library
import pandas as pd

def create_df_and_drop_columns(parsed_tweet):
    try:
        df_treated = pd.DataFrame(parsed_tweet).reset_index(drop=True).iloc[:1]

        df_treated.drop(columns=['quote_count', 'reply_count', 'retweet_count',
                             'favorite_count', 'favorited', 'retweeted', 
                             'user', 'retweeted_status', 'entities'], inplace=True)

        return df_treated
    
    except:
        return None

# ------------------------------------------------------------------------------

def tweet_to_df_(parsed_tweet):
    try:
        user_mentions = [user for user in parsed_tweet["entities"]["user_mentions"]]

        df = pd.DataFrame(user_mentions).rename(columns={
                                        "screen_name": "entities_screen_name",
                                        "name": "entities_name",
                                        "id": "entities_id",
                                        "id_str": "entities_id_str"
                                    })

        return df
    except:
        return None
    
# ------------------------------------------------------------------------------
    

def rename_columns(df, parsed_tweet):
    df["user_id"] = parsed_tweet["user"]["id"]
    df["user_id_str"] = parsed_tweet["user"]["id_str"]
    df["user_screen_name"] = parsed_tweet["user"]["screen_name"]
    df["user_location"] = parsed_tweet["user"]["location"]
    df["user_description"] = parsed_tweet["user"]["description"]
    df["user_protected"] = parsed_tweet["user"]["protected"]
    df["user_verified"] = parsed_tweet["user"]["verified"]
    df["user_followers_count"] = parsed_tweet["user"]["followers_count"]
    df["user_friends_count"] = parsed_tweet["user"]["friends_count"]
    df["user_created_at"] = parsed_tweet["user"]["created_at"]
    
    return df

# %%
# list of Pandas Dataframe object
treateds_df = [create_df_and_drop_columns(tweet) for tweet in parsed_tweets]

# %%
# Remove None values
treateds_df = [df for df in treateds_df if df is not None]

# %%
# Verify len
len(treateds_df)
# Out:
# 1061

# %%
# Concat all Dataframes in treateds_df list
final_df = pd.concat(treateds_df, ignore_index=True)

# %%
# check final df
final_df
# Out:
#                           created_at                   id  \
# 0     Wed Nov 25 18:40:18 +0000 2020  1331669054852100099
# 1     Wed Nov 25 18:40:18 +0000 2020  1331669054977961984
# 2     Wed Nov 25 18:40:18 +0000 2020  1331669054956953600
# 3     Wed Nov 25 18:40:18 +0000 2020  1331669054923411457
# 4     Wed Nov 25 18:40:18 +0000 2020  1331669055137263619
# ...                              ...                  ...
# 1056  Wed Nov 25 18:40:51 +0000 2020  1331669192827936769
# 1057  Wed Nov 25 18:40:51 +0000 2020  1331669194459537408
# 1058  Wed Nov 25 18:40:51 +0000 2020  1331669194455326724
# 1059  Wed Nov 25 18:40:51 +0000 2020  1331669194652278784
# 1060  Wed Nov 25 18:40:51 +0000 2020  1331669194694332419
#
#                    id_str                                               text  \
# 0     1331669054852100099  RT @IvyKungu: why are you saying this like it’...
# 1     1331669054977961984  RT @EinsteinsMagic: Racist Demonic Obama, blam...
# 2     1331669054956953600  RT @gatewaypundit: We spoke with a top Trump a...
# 3     1331669054923411457  RT @donwinslow: And tens of millions of us are...
# 4     1331669055137263619  RT @jimsciutto: “My family voted for him, dona...
# ...                   ...                                                ...
# 1056  1331669192827936769  RT @marceelias: 🚨NEW: Republicans have dismiss...
# 1057  1331669194459537408  RT @EpochTimes: “We now believe that Donald Tr...
# 1058  1331669194455326724       RT @realDonaldTrump: https://t.co/e7giu2jEG1
# 1059  1331669194652278784  RT @dbongino: Only a Democrat could say someth...
# 1060  1331669194694332419  RT @votevets: The current and soon to be evict...
#
#                                                  source  truncated  \
# 0     <a href="http://twitter.com/download/android" ...      False
# 1     <a href="http://twitter.com/download/iphone" r...      False
# 2     <a href="http://twitter.com/download/iphone" r...      False
# 3     <a href="https://mobile.twitter.com" rel="nofo...      False
# 4     <a href="http://twitter.com/download/android" ...      False
# ...                                                 ...        ...
# 1056  <a href="https://mobile.twitter.com" rel="nofo...      False
# 1057  <a href="http://twitter.com/download/iphone" r...      False
# 1058  <a href="http://twitter.com/download/iphone" r...      False
# 1059  <a href="http://twitter.com/download/android" ...      False
# 1060  <a href="http://twitter.com/download/android" ...      False
#
#      in_reply_to_status_id in_reply_to_status_id_str in_reply_to_user_id  \
# 0                     None                      None                None
# 1                     None                      None                None
# 2                     None                      None                None
# 3                     None                      None                None
# 4                     None                      None                None
# ...                    ...                       ...                 ...
# 1056                  None                      None                None
# 1057                  None                      None                None
# 1058                  None                      None                None
# 1059                  None                      None                None
# 1060                  None                      None                None
#
#      in_reply_to_user_id_str  ... quoted_status_id quoted_status_id_str  \
# 0                       None  ...     1.331330e+18  1331330446458638336
# 1                       None  ...              NaN                  NaN
# 2                       None  ...              NaN                  NaN
# 3                       None  ...     1.331654e+18  1331653915553751042
# 4                       None  ...              NaN                  NaN
# ...                      ...  ...              ...                  ...
# 1056                    None  ...              NaN                  NaN
# 1057                    None  ...              NaN                  NaN
# 1058                    None  ...     1.331329e+18  1331328530391719937
# 1059                    None  ...              NaN                  NaN
# 1060                    None  ...              NaN                  NaN
#
#             quoted_status quoted_status_permalink is_quote_status  \
# 0     1331330446458638336                     NaN            True
# 1                     NaN                     NaN           False
# 2                     NaN                     NaN           False
# 3     1331653915553751042                     NaN            True
# 4                     NaN                     NaN           False
# ...                   ...                     ...             ...
# 1056                  NaN                     NaN           False
# 1057                  NaN                     NaN           False
# 1058  1331328530391719937                     NaN            True
# 1059                  NaN                     NaN           False
# 1060                  NaN                     NaN           False
#
#       filter_level lang   timestamp_ms possibly_sensitive  extended_entities
# 0              low   en  1606329618548                NaN                NaN
# 1              low   en  1606329618578                NaN                NaN
# 2              low   en  1606329618573                NaN                NaN
# 3              low   en  1606329618565              False                NaN
# 4              low   en  1606329618616                NaN                NaN
# ...            ...  ...            ...                ...                ...
# 1056           low   en  1606329651444                NaN                NaN
# 1057           low   en  1606329651833                NaN                NaN
# 1058           low  und  1606329651832              False                NaN
# 1059           low   en  1606329651879              False                NaN
# 1060           low   en  1606329651889                NaN                NaN
#
# [1061 rows x 25 columns]

# %% [markdown]
# ### Ingestão de dados do Twitter no SQL Server

# %%
# import libraries
import pyodbc
import sqlalchemy

# %%
# create engine connection with sql server
engine = sqlalchemy.create_engine(
    "mssql+pyodbc://[server_name]/twitter?driver=ODBC+Driver+17+for+SQL+Server?Trusted_Connection=yes"
)

# %%
# inserting tweets (Pandas Dataframe) into SQL server Database
final_df.to_sql("tweets", con=engine, index=False, if_exists='append')
